# %% [markdown]
# # BASIC LIBRARIES

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # UPLOAD THE DATA_SET

# %%
df=pd.read_csv(r'C:\Users\R\Desktop\Dataset\adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.nunique()
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt           48842.0  189664.134597  105604.025423  12285.0  117550.5
# educational-num  48842.0      10.078089       2.570973      1.0       9.0
# capital-gain     48842.0    1079.067626    7452.019058      0.0       0.0
# capital-loss     48842.0      87.502314     403.004552      0.0       0.0
# hours-per-week   48842.0      40.422382      12.391444      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      48.0       90.0
# fnlwgt           178144.5  237642.0  1490400.0
# educational-num      10.0      12.0       16.0
# capital-gain          0.0       0.0    99999.0
# capital-loss          0.0       0.0     4356.0
# hours-per-week       40.0      45.0       99.0

# %% [markdown]
# # value_count

# %%
df['age'].value_counts()
# Out:
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, Length: 74, dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df['fnlwgt'].value_counts()
# Out:
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 188488     1
# 285290     1
# 293579     1
# 114874     1
# 257302     1
# Name: fnlwgt, Length: 28523, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df['educational-num'].value_counts()
# Out:
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['relationship'].value_counts()
# Out:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
df['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
df['capital-gain'].value_counts()
# Out:
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 7262         1
# 22040        1
# 1639         1
# 2387         1
# Name: capital-gain, Length: 123, dtype: int64

# %%
df['capital-loss'].value_counts()
# Out:
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 2465        1
# 2080        1
# 155         1
# 1911        1
# 2201        1
# Name: capital-loss, Length: 99, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %%
df['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# # FILLING (?) VALUES

# %% [markdown]
# REPLACE THE VALUE WITH MODE

# %%
df['workclass'] = df['workclass'].replace('?','private')
df['occupation'] = df['occupation'].replace('?','Prof-specialty')
df['native-country'] = df['native-country'].replace('?','United-States')
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18           private  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29           private  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # FEATURE ENGINEERING

# %%
df.education = df.education.replace(['preschool','1st-4th','5th-6th','7th-8th','9th-10th','11th-12th'],'school')
df.education = df.education.replace('HS-grad','highschool')
df.education = df.education.replace(['some-college','Assoc-voc','Assoc-acdm','prof-school'],'higher')
df.education = df.education.replace('Bachelors','graduate')
df.education = df.education.replace('Masters','postgraduate')
df.education = df.education.replace('Doctorate','phd')

# %%
df.education
# Out:
# 0                11th
# 1          highschool
# 2              higher
# 3        Some-college
# 4        Some-college
#              ...
# 48837          higher
# 48838      highschool
# 48839      highschool
# 48840      highschool
# 48841      highschool
# Name: education, Length: 48842, dtype: object

# %%
df['marital-status'] = df['marital-status'].replace(['Married-civ-spouse','Married-AF-spouse'],'married') 
df['marital-status'] = df['marital-status'].replace('Never-married','notmarried')
df['marital-status'] = df['marital-status'].replace(['Divorced','Separated','Widowed','Married-spouse-absent'],'other') 
df['marital-status']
# Out:
# 0        notmarried
# 1           married
# 2           married
# 3           married
# 4        notmarried
#             ...
# 48837       married
# 48838       married
# 48839         other
# 48840    notmarried
# 48841       married
# Name: marital-status, Length: 48842, dtype: object

# %%
df.income = df.income.replace('<=50K',0)
df.income = df.income.replace('>50K',1)
df.income
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 48842, dtype: int64

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814    highschool                9
# 2   28         Local-gov  336951        higher               12
# 3   44           Private  160323  Some-college               10
# 4   18           private  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29           private  227026    highschool                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996        school                4
#
#   marital-status         occupation   relationship   race  gender  \
# 0     notmarried  Machine-op-inspct      Own-child  Black    Male
# 1        married    Farming-fishing        Husband  White    Male
# ...

# %%
df['marital-status'].value_counts()
# Out:
# married       22416
# notmarried    16117
# other         10309
# Name: marital-status, dtype: int64

# %%
df['income'].value_counts()
# Out:
# 0    37155
# 1    11687
# Name: income, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                       age    fnlwgt  educational-num  capital-gain  \
# age              1.000000 -0.076628         0.030940      0.077229
# fnlwgt          -0.076628  1.000000        -0.038761     -0.003706
# educational-num  0.030940 -0.038761         1.000000      0.125146
# capital-gain     0.077229 -0.003706         0.125146      1.000000
# capital-loss     0.056944 -0.004366         0.080972     -0.031441
# hours-per-week   0.071558 -0.013519         0.143689      0.082157
# income           0.230369 -0.006339         0.332613      0.223013
#
#                  capital-loss  hours-per-week    income
# age                  0.056944        0.071558  0.230369
# fnlwgt              -0.004366       -0.013519 -0.006339
# educational-num      0.080972        0.143689  0.332613
# capital-gain        -0.031441        0.082157  0.223013
# capital-loss         1.000000        0.054467  0.147554
# hours-per-week       0.054467        1.000000  0.227687
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # Histogram

# %%
df.hist(figsize=(10,10),layout=(3,3),sharex=False)
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'fnlwgt'}>,
#         <Axes: title={'center': 'educational-num'}>],
#        [<Axes: title={'center': 'capital-gain'}>,
#         <Axes: title={'center': 'capital-loss'}>,
#         <Axes: title={'center': 'hours-per-week'}>],
#        [<Axes: title={'center': 'income'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # BOX_PLOT

# %%
df.plot(kind='box',figsize=(10,10),layout=(3,3),sharex=False,subplots=True)
# Out:
# age                   Axes(0.125,0.653529;0.227941x0.226471)
# fnlwgt             Axes(0.398529,0.653529;0.227941x0.226471)
# educational-num    Axes(0.672059,0.653529;0.227941x0.226471)
# capital-gain          Axes(0.125,0.381765;0.227941x0.226471)
# capital-loss       Axes(0.398529,0.381765;0.227941x0.226471)
# hours-per-week     Axes(0.672059,0.381765;0.227941x0.226471)
# income                    Axes(0.125,0.11;0.227941x0.226471)
# dtype: object

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# (Histograph)

# %%
plt.hist(df['age'])
# Out:
# (array([8432., 8686., 9120., 9157., 5965., 3876., 2456.,  777.,  277.,
#           96.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['fnlwgt'])
# Out:
# (array([1.9939e+04, 2.2790e+04, 5.2250e+03, 6.7300e+02, 1.5100e+02,
#         3.5000e+01, 1.5000e+01, 7.0000e+00, 3.0000e+00, 4.0000e+00]),
#  array([  12285. ,  160096.5,  307908. ,  455719.5,  603531. ,  751342.5,
#          899154. , 1046965.5, 1194777. , 1342588.5, 1490400. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['educational-num'])
# Out:
# (array([  330.,   509.,  1711.,  1389.,  2469., 15784., 12939.,  1601.,
#         10682.,  1428.]),
#  array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['capital-gain'])
# Out:
# (array([4.7708e+04, 7.5300e+02, 1.2800e+02, 6.0000e+00, 3.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.4400e+02]),
#  array([    0. ,  9999.9, 19999.8, 29999.7, 39999.6, 49999.5, 59999.4,
#         69999.3, 79999.2, 89999.1, 99999. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['capital-loss'])
# Out:
# (array([4.6574e+04, 2.3000e+01, 2.9000e+01, 7.0600e+02, 1.1690e+03,
#         3.0700e+02, 2.1000e+01, 2.0000e+00, 8.0000e+00, 3.0000e+00]),
#  array([   0. ,  435.6,  871.2, 1306.8, 1742.4, 2178. , 2613.6, 3049.2,
#         3484.8, 3920.4, 4356. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['hours-per-week'])
# Out:
# (array([ 1125.,  3328.,  3398., 26639.,  4671.,  5828.,  2642.,   683.,
#           315.,   213.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# PROBABILITY DENSITY FUNCTION(PDF)

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['fnlwgt'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\3205066975.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fnlwgt'])
# <Axes: xlabel='fnlwgt', ylabel='Density'>

# %%
sns.distplot(df['educational-num'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\578307260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['educational-num'])
# <Axes: xlabel='educational-num', ylabel='Density'>

# %%
sns.distplot(df['capital-gain'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\3718591533.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['capital-gain'])
# <Axes: xlabel='capital-gain', ylabel='Density'>

# %%
sns.distplot(df['capital-loss'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\3559393560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['capital-loss'])
# <Axes: xlabel='capital-loss', ylabel='Density'>

# %%
sns.distplot(df['hours-per-week'])
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_17492\1366286883.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['hours-per-week'])
# <Axes: xlabel='hours-per-week', ylabel='Density'>

# %% [markdown]
# BOX_PLOT

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['fnlwgt'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['educational-num'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['capital-gain'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['capital-loss'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['hours-per-week'])
# Out:
# <Axes: >

# %% [markdown]
# # UNIVARIATE(CATEGORICAL)

# %%
df['workclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['education'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['marital-status'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['occupation'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['relationship'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['race'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['native-country'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Bivariate Analysis
# scatterplot(Numerical-Numerical)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['hours-per-week'])
plt.xlabel('Age')
plt.ylabel('Hours Per Week')
plt.title('Age vs. Hours Per Week')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['fnlwgt'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('FNLWGT')
plt.title('Age vs. FNLWGT')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['educational-num'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('ed-num')
plt.title('Age vs. ed-num')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['capital-gain'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('capital-gain')
plt.title('Age vs. capitalgain')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['capital-loss'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('capitalloss')
plt.title('Age vs. capitalloss')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['income'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('income')
plt.title('Age vs. income')
plt.show()

# %% [markdown]
# # Barplot
# (Numerical-Categorical)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='education', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Education Level vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='workclass', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Workclass vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='marital-status', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Maritalstatus')
plt.ylabel('Count')
plt.title('Maritalstatus vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='occupation', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Occupation vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='relationship', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Relationship')
plt.ylabel('Count')
plt.title('Relationship vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='race', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Race')
plt.ylabel('Count')
plt.title('Race vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='gender', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('gender vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='native-country', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Native country')
plt.ylabel('Count')
plt.title('Native country vs. Income')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Box plot
# (numerical-categorical)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='workclass', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Workclass')
plt.ylabel('Income')
plt.title('Workclass vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='education', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Education vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='marital-status', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Maritalstatus')
plt.ylabel('Income')
plt.title('Maritalstatus vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='occupation', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Occupation')
plt.ylabel('Income')
plt.title('Occupation vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='relationship', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Relationship')
plt.ylabel('Income')
plt.title('Relationship vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='race', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Race')
plt.ylabel('Income')
plt.title('Race vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Gender')
plt.ylabel('Income')
plt.title('Gender vs. Income')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='native-country', y='income', data=df, palette='Set3')
plt.xticks(rotation=45)
plt.xlabel('Native-country')
plt.ylabel('Income')
plt.title('Native-country vs. Income')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Multivariate
# Scatterplot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='educational-num', hue='income', data=df, palette='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Education Level')
plt.title('Age vs. Education Level (Color: Income)')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='age', y='fnlwgt', hue='income', data=df, palette='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Fnlwgt')
plt.title('Age vs. Fnlwgt (Color: Income)')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='age', y='capital-gain', hue='income', data=df, palette='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Capital-gain')
plt.title('Age vs. Capital-gain (Color: Income)')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='age', y='capital-loss', hue='income', data=df, palette='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Capital-loss')
plt.title('Age vs. Capital-loss (Color: Income)')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='age', y='hours-per-week', hue='income', data=df, palette='coolwarm', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Hoursperweek')
plt.title('Age vs. Hoursperweek (Color: Income)')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Swarm plot

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='education', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Education Level')
plt.ylabel('Age')
plt.title('Age vs. Education vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='workclass', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Workclass')
plt.ylabel('Age')
plt.title('Age vs. Workclass vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='marital-status', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Marital-status')
plt.ylabel('Age')
plt.title('Age vs. Marital-status vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='occupation', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Occupation')
plt.ylabel('Age')
plt.title('Age vs. Occupation vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='relationship', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Relationship')
plt.ylabel('Age')
plt.title('Age vs. Relationship vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='race', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Race')
plt.ylabel('Age')
plt.title('Age vs. Race vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='gender', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age vs. Gender vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(x='native-country', y='age', hue='income', data=df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Native-country')
plt.ylabel('Age')
plt.title('Age vs. Native-country vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Multivariate
# (Violin plot)

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='workclass', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Workclass')
plt.ylabel('Age')
plt.title('Age vs. Workclass vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='education', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Education')
plt.ylabel('Age')
plt.title('Age vs. Education vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='marital-status', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Marital-status')
plt.ylabel('Age')
plt.title('Age vs. Mariatl-status vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='occupation', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Occupation')
plt.ylabel('Age')
plt.title('Age vs. Occupation vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='relationship', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Relationship')
plt.ylabel('Age')
plt.title('Age vs. Relationship vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='race', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Race')
plt.ylabel('Age')
plt.title('Age vs. Race vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='gender', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age vs. Gender vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='native-country', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Native-country')
plt.ylabel('Age')
plt.title('Age vs. Native-country vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()
