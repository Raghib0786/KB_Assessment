# %% [markdown]
# # Importing Basic Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Upload the Data set

# %%
df=pd.read_csv(r'C:\Users\R\Desktop\Dataset\adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.size
# Out:
# 732630

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
numerical = df.select_dtypes(include=['number']).columns
categorical = df.select_dtypes(include=['object']).columns

print("Numerical columns:")
print(numerical)

print("\n Categorical columns:")
print(categorical)

print
# Out:
# Numerical columns:
# Index(['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')
#
#  Categorical columns:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'gender', 'native-country', 'income'],
#       dtype='object')
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# # observation
#
# -> 'age','fnlwgt','educational-num', 'capital-gain', 'capital-loss','hours-per-week' are the numerical columns in the data set
#
# -> 'workclass', 'education', 'marital-status', 'occupation','relationship', 'race', 'gender', 'native-country', 'income' are the categorical columns in the data set)

# %% [markdown]
# # Value_counts

# %%
df['age'].value_counts()
# Out:
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: age, Length: 74, dtype: int64

# %%
df['fnlwgt'].value_counts()
# Out:
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 188488     1
# 285290     1
# 293579     1
# 114874     1
# 257302     1
# Name: fnlwgt, Length: 28523, dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df['educational-num'].value_counts()
# Out:
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: educational-num, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['relationship'].value_counts()
# Out:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
df['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
df['capital-gain'].value_counts()
# Out:
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 7262         1
# 22040        1
# 1639         1
# 2387         1
# Name: capital-gain, Length: 123, dtype: int64

# %%
df['capital-loss'].value_counts()
# Out:
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 2465        1
# 2080        1
# 155         1
# 1911        1
# 2201        1
# Name: capital-loss, Length: 99, dtype: int64

# %%
df['hours-per-week'].value_counts()
# Out:
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
#       ...
# 69        1
# 87        1
# 94        1
# 82        1
# 79        1
# Name: hours-per-week, Length: 96, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %%
df['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# # Observation
#
# -> workclass, occupation, native_country having a unknown values "?".
#
# -> we have to replace "?" values

# %%
df=df.replace("?",np.nan)

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %% [markdown]
# # Removing Duplicates Data

# %%
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # Observation
#
# -> (48842-48790=52)
#
# -> There are 52 duplicated rows in the dataset

# %% [markdown]
# # EDA
#
# -> Univariate Analysis
#
# 1.Numerical_Data

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of Age")
sns.boxplot(df['age'])


plt.subplot(1, 3, 2)
plt.title("Histogram of Age")
plt.hist(df['age'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of Age")
sns.histplot(df['age'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)
iqr=q3-q1

# %%
q1,q3,iqr
# Out:
# (28.0, 48.0, 20.0)

# %% [markdown]
# # Observation
#
# -> Minimum age=17
#
# -> Maximum age= 90
#
# -> Outliers are 80-90
#
# -> Q1=28,Q3=48
#
# -> IQR=Q3-Q1=20
#
# -> Median=38
#
# -> The highest frequency age of the workers lies between the range of (30 - 40)
#
# -> Its positively skewed means , The Mean > Median , Outliers on the right side (PDF of Age)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of fnlwgt")
sns.boxplot(df['fnlwgt'])


plt.subplot(1, 3, 2)
plt.title("Histogram of fnlwgt")
plt.hist(df['fnlwgt'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of fnlwgt")
sns.histplot(df['fnlwgt'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['fnlwgt'].quantile(0.25)
q3=df['fnlwgt'].quantile(0.75)
iqr=q3-q1

# %% [markdown]
#  # Observation
#
# -> Minimum fnlwgt=0.12
#
# -> Maximum age= 1.4
#
# -> Outliers are 0.45-1.45
#
# -> Q1=0.24,Q3=0.12
#
# -> IQR=Q3-Q1=0.12
#
# -> Median=0.18
#
# -> The highest frequency fnlwgt of the workers lies between the range of (0.2 - 0.25)
#
# -> Its positively skewed means , The Mean > Median , Outliers on the right side (PDF of Age)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of educational-num")
sns.boxplot(df['educational-num'])


plt.subplot(1, 3, 2)
plt.title("Histogram of educational-num")
plt.hist(df['educational-num'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of educational-num")
sns.histplot(df['educational-num'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['educational-num'].quantile(0.25)
q3=df['educational-num'].quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# 9.0 12.0 3.0

# %% [markdown]
# # Observation
#
# -> Minimum educational-num=01yrs
#
# -> Maximum educational-num= 16yrs
#
# -> Outliers are (01-05)
#
# -> Q1=9,Q3=12
#
# -> IQR=Q3-Q1=03
#
# -> Median=11yrs(aprox)
#
# -> The highest frequency educational-num of the workers lies between the range of (09 - 10)yrs

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of capital-gain")
sns.boxplot(df['capital-gain'])


plt.subplot(1, 3, 2)
plt.title("Histogram of capital-gain")
plt.hist(df['capital-gain'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of capital-gain")
sns.histplot(df['capital-gain'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['capital-gain'].quantile(0.25)
q3=df['capital-gain'].quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# 0.0 0.0 0.0

# %% [markdown]
# # Observation
#
# -> The 'capital-gain' data is heavily skewed and concentrated at 0.
#
# -> Most individuals in the dataset do not have any capital gains.
#
# -> There are very few instances where 'capital-gain' is not 0.
#
# -> The 'capital-gain' column is highly skewed towards 0, with the vast majority of values being 0. This suggests that for most    individuals in the dataset, there is no capital gain reported.

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of capital-loss")
sns.boxplot(df['capital-loss'])


plt.subplot(1, 3, 2)
plt.title("Histogram of capital-loss")
plt.hist(df['capital-loss'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of capital-loss")
sns.histplot(df['capital-loss'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['capital-loss'].quantile(0.25)
q3=df['capital-loss'].quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# 0.0 0.0 0.0

# %% [markdown]
# # Observation
# -> The 'capital-loss' data is heavily skewed and concentrated at 0.
#
# -> Most individuals in the dataset do not have any capital loss.
#
# -> There are very few instances where 'capital-loss' is not 0.
#
# -> The 'capital-loss' column is highly skewed towards 0, with the vast majority of values being 0. This suggests that for most individuals in the dataset, there is no capital loss reported.

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Boxplot of hours-per-week")
sns.boxplot(df['hours-per-week'])


plt.subplot(1, 3, 2)
plt.title("Histogram of hours-per-week")
plt.hist(df['hours-per-week'], bins=20)  

plt.subplot(1, 3, 3)
plt.title("Probability Density Function (PDF) of hours-per-week")
sns.histplot(df['hours-per-week'], kde= True)  

plt.tight_layout()
plt.show()

# %%
q1=df['hours-per-week'].quantile(0.25)
q3=df['hours-per-week'].quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# 40.0 45.0 5.0

# %% [markdown]
# # Observation
#
# -> The boxplot shows a moderate range of values for 'hours-per-week', with a median (Q2) around 40-45 hours.
#
# -> There are some outliers beyond the upper whisker in the boxplot.
#
# -> The histogram shows a peak around 40-45 hours per week, which is also where the median lies.
#
# -> The IQR is 5.0, indicating that the middle 50% of the 'hours-per-week' values fall within the range of 40 to 45 hours.
#
# -> The mean and median are relatively close, indicating that the distribution of 'hours-per-week' is approximately symmetric or    slightly right-skewed.

# %% [markdown]
# # Univariate
# 2.(Categorical)

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='workclass', data=df)
plt.title('Workclass Distribution')
plt.subplot(1, 2, 2)
pie =df['workclass'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('Workclass Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Workclass Distribution Countplot:
#
# ->  The most common workclass category is 'Private', followed by 'Self-emp-not-inc' and 'Local-gov'.
#
# -> 'Private' workclass is significantly more prevalent compared to other categories.
#
# -> 'Self-emp-not-inc' and 'Local-gov' have decent representation but are much lower in count compared to 'Private'.
#
# **Workclass Proportion Pie Chart:
#
# -> 'Private' workclass dominates the pie chart, representing the largest portion of the dataset.
#
# -> 'Self-emp-not-inc' and 'Local-gov' are the next most significant categories but are smaller compared to 'Private'.
#
# -> Other workclass categories such as 'Federal-gov', 'Self-emp-inc', 'State-gov', 'Without-pay', and 'Never-worked'                collectively make up a relatively small portion of the dataset.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='education', data=df)
plt.title('education Distribution')
plt.subplot(1, 2, 2)
pie =df['education'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('education Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Education Distribution Countplot:
#
# -> The most common education category is 'HS-grad' (High School Graduate), followed by 'Some-college' and 'Bachelors'.
#
# -> Categories such as '11th', '10th', '7th-8th', 'Prof-school', 'Assoc-acdm', and 'Assoc-voc' have lower counts compared to the    top three.
#
# -> 'Masters', 'Doctorate', '9th', '12th', and '5th-6th' have the lowest counts in the dataset.
#
# **Education Proportion Pie Chart:
#
# -> 'HS-grad' (High School Graduate) is the largest category, representing a significant portion of the dataset.
#
# -> 'Some-college' and 'Bachelors' are also notable categories, but they are smaller compared to 'HS-grad'.
#
# -> 'Masters', 'Doctorate', '9th', '12th', and '5th-6th' have smaller portions of the pie, indicating they are less common in       the dataset.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='marital-status', data=df)
plt.title('marital-status Distribution')
plt.subplot(1, 2, 2)
pie =df['marital-status'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('marital-status Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Marital Status Distribution Countplot:
#
# -> The most common marital status is 'Married-civ-spouse', followed by 'Never-married' and 'Divorced'.
#
# -> 'Separated', 'Widowed', 'Married-spouse-absent', and 'Married-AF-spouse' have lower counts compared to the top three.
#
# -> 'Never-married' and 'Married-civ-spouse' are the two most prominent categories in the dataset.
#
# **Marital Status Proportion Pie Chart:
#
# ->'Married-civ-spouse' is the largest category, representing a significant portion of the dataset.
#
# -> 'Never-married' is the second-largest category but is smaller compared to 'Married-civ-spouse'.
#
# -> Other categories like 'Divorced', 'Separated', 'Widowed', 'Married-spouse-absent', and 'Married-AF-spouse' have smaller        proportions.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='occupation', data=df)
plt.title('occupation Distribution')
plt.subplot(1, 2, 2)
pie =df['occupation'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('occupation Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Occupation Distribution Countplot:
#
# -> The most common occupation category is 'Prof-specialty' (Professional specialty), followed by 'Craft-repair' and 'Exec-        managerial'.
#
# -> Categories such as 'Adm-clerical', 'Sales', 'Other-service', 'Machine-op-inspct', and 'Transport-moving' have lower counts      compared to the top three.
#
# -> 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', and 'Armed-Forces' have the       lowest counts in the dataset.
#
# **Occupation Proportion Pie Chart:
#
# -> 'Prof-specialty' is the largest category in the pie chart, representing a significant portion of the dataset.
#
# -> 'Craft-repair' and 'Exec-managerial' are also notable categories but are smaller compared to 'Prof-specialty'.
#
# -> Other categories like 'Adm-clerical', 'Sales', 'Other-service', 'Machine-op-inspct', and 'Transport-moving' have smaller        proportions in the pie chart.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='relationship', data=df)
plt.title('relationship Distribution')
plt.subplot(1, 2, 2)
pie =df['relationship'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('relationship Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# -> The 'relationship' column shows the distribution of individuals' relationships within the family.
#
# -> 'Husband' is the most common relationship category, indicating a significant proportion of the dataset consists of husbands.
#
# -> 'Not-in-family' and 'Own-child' are also well-represented categories but are smaller compared to 'Husband'.
#
# -> Categories like 'Unmarried', 'Wife', and 'Other-relative' are less common in the dataset.
#
# -> The pie chart illustrates the dominance of 'Husband' and shows the relative proportions of other relationship categories.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='race', data=df)
plt.title('race Distribution')
plt.subplot(1, 2, 2)
pie =df['race'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('race Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# ->  The 'race' column shows the distribution of individuals based on their race.
#
# -> 'White' is the most common race category, indicating a significant proportion of the dataset consists of individuals of         White race.
#
# ->  'Black' and 'Asian-Pac-Islander' are also well-represented categories but are smaller compared to 'White'.
#
# ->  Categories like 'Amer-Indian-Eskimo' and 'Other' are less common in the dataset.
#
# ->  The pie chart illustrates the dominance of 'White' and shows the relative proportions of other race categories.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='gender', data=df)
plt.title('gender Distribution')
plt.subplot(1, 2, 2)
pie =df['gender'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('gender Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# -> The 'gender' column shows the distribution of individuals based on their gender.
#
# -> 'Male' is the most common gender category, indicating a majority of the dataset consists of males.
#
# -> 'Female' is the smaller category, representing a smaller proportion compared to 'Male'.

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='native-country', data=df)  
plt.title('Distribution of native-country')
plt.xlabel('native-country')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Observation
#
# -> The 'native-country' column shows the distribution of individuals based on their native country.
#
# -> 'United-States' is the most common native country category, indicating a majority of the dataset consists of individuals         from the United States.
#
# ->  'Mexico' and 'Philippines' are also well-represented categories but are smaller compared to 'United-States'.
#
# ->  Countries like 'Laos', 'Thailand', 'Outlying-US(Guam-USVI-etc)', 'Hungary', 'Holand-Netherlands', 'Scotland', and 'Hong'       are less common in the dataset.

# %%
plt.figure(figsize=(22, 5))
plt.subplot(1, 2, 1)
sns.countplot(x='income', data=df)
plt.title('income Distribution')
plt.subplot(1, 2, 2)
pie =df['income'].value_counts().plot.pie(autopct='%1.1f%%', rotatelabels = True )
plt.title('income Proportion')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')  

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# -> The 'income' column shows a binary classification of individuals based on their income level.
#
# -> The majority of individuals in the dataset have an income of '<=50K', representing a larger portion of the dataset.
#
# -> The '<=50K' category is significantly more prevalent than the '>50K' category.
#
# -> The pie chart visually confirms this imbalance, with the '<=50K' segment occupying a much larger portion compared to the        '>50K' segment.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='age', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('age Level')
plt.ylabel('Count')
plt.title('Age Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Younger Ages:
#
# -> There are more individuals in the '<=50K' income category across most age levels, especially for younger ages.
#
# -> This is expected as younger individuals might be early in their careers or education, leading to lower incomes.
#
# **Middle Ages (Around 40s-50s):
#
# -> The '>50K' income category starts to become more prominent in the middle age ranges.
#
# -> This suggests that individuals in their 40s and 50s tend to have a higher representation in the higher income category.
#
# **Older Ages (60s and above):
#
# -> In the '>50K' income category, there is a noticeable decrease in the count as age increases, especially in the 60s and above.
#
# -> This could be due to retirement or a decrease in employment rates among older individuals.
#
# **Overall:
#
# The distribution of income levels across age groups suggests that income tends to increase with age until a certain point (around middle age), after which it might decline, especially in retirement ages.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='workclass', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('workclass Level')
plt.ylabel('Count')
plt.title('Workclass Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Private Workclass:
#
# -> The 'Private' workclass has the highest number of individuals in both income categories ('>50K' and '<=50K').
#
# -> This suggests that a large portion of the dataset consists of individuals employed in the private sector, with varied income    levels.
#
# **Self-Employed Workclass:
#
# -> The 'Self-employed-not-inc' and 'Self-employed-inc' categories have a higher proportion of individuals in the '>50K' income    category compared to the '<=50K' category.
#
# -> This indicates that self-employed individuals, whether incorporated or not, tend to have a higher representation in the        higher income category.
#
# **Government Workclass:
#
# -> 'Local-gov' and 'Federal-gov' categories have a noticeable proportion of individuals in the '>50K' income category.
#
# -> This suggests that individuals working for local or federal government positions are more likely to have higher incomes.
#    Other Workclass Categories:
#
# -> Categories like 'State-gov', 'Without-pay', and 'Never-worked' have very few individuals in the '>50K' income category.
#
# -> 'Without-pay' and 'Never-worked' categories have the smallest counts, indicating they are the least common and likely do not    contribute significantly to the income distribution.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='education', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('education Level')
plt.ylabel('Count')
plt.title('Education Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Higher Education Levels (Bachelors, Masters, Doctorate):
#
# -> Individuals with higher education levels such as 'Bachelors', 'Masters', and 'Doctorate' tend to have a higher                  representation in the '>50K' income category.
#
# -> This suggests that higher education levels are correlated with higher income levels.
#
# **Lower Education Levels (HS-grad, Some-college, 11th, 10th, 7th-8th, 9th, 12th, 5th-6th, 1st-4th):
#
# -> Categories with lower education levels like 'HS-grad', 'Some-college', '11th', '10th', '7th-8th', '9th', '12th', '5th-6th',    and '1st-4th' have a higher representation in the '<=50K' income category.
#
# -> This indicates that individuals with lower education levels are more likely to have incomes below 50K.
#
# **Middle Education Levels (Assoc-acdm, Assoc-voc, Prof-school):
#
# -> 'Assoc-acdm', 'Assoc-voc', and 'Prof-school' have a mix of individuals in both income categories, but with a slightly higher     count in the '>50K' income category.
#
# -> These categories represent a middle ground in terms of education and income levels.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='occupation', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('occupation Level')
plt.ylabel('Count')
plt.title('Occupation Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Professional and Managerial Occupations (Prof-specialty, Exec-managerial):
#
# -> 'Prof-specialty' and 'Exec-managerial' categories have a higher representation in the '>50K' income category.
#
# -> This suggests that individuals in professional and managerial occupations tend to have higher incomes.
#
# **Technical and Administrative Occupations (Tech-support, Adm-clerical):
#
# -> 'Tech-support' has a relatively balanced distribution in both income categories.
#
# -> 'Adm-clerical' has a higher representation in the '<=50K' income category.
#
# -> Individuals in administrative and clerical roles are more likely to have incomes below 50K.
#
# **Service and Blue-collar Occupations (Handlers-cleaners, Craft-repair, Transport-moving, Machine-op-inspct, Other-service,
#   Farming-fishing, Protective-serv, Priv-house-serv):
#
# -> These categories generally have a higher count in the '<=50K' income category.
#
# -> This indicates that service, blue-collar, and manual labor occupations tend to have lower income levels.
#
# **Sales and Military Occupations (Sales, Armed-Forces):
#
# -> 'Sales' has a relatively balanced distribution in both income categories.
#
# ->'Armed-Forces' has a very small count, indicating it is the least common occupation in the dataset.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='marital-status', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('marital-status Level')
plt.ylabel('Count')
plt.title('Marital-status Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Married Individuals (Married-civ-spouse, Married-AF-spouse):
#
# -> 'Married-civ-spouse' and 'Married-AF-spouse' categories have a higher representation in the '>50K' income category.
#
# ->This suggests that married individuals are more likely to have higher incomes compared to other marital statuses.
#
# **Never Married:
#
# -> 'Never-married' individuals have a higher count in the '<=50K' income category.
#
# -> This indicates that individuals who have never been married tend to have lower incomes.
#
# **Divorced and Separated Individuals (Divorced, Separated):
#
# -> 'Divorced' and 'Separated' categories have a mix of individuals in both income categories, but with a higher count in the      '<=50K' income category.
#
# -> This suggests that individuals who are divorced or separated are more likely to have lower incomes.
#
# **Widowed Individuals (Widowed):
#
# -> 'Widowed' individuals have a higher count in the '<=50K' income category.
#
# -> This indicates that widowed individuals tend to have lower incomes.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='race', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('race Level')
plt.ylabel('Count')
plt.title('Race Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **White:
#
# -> The 'White' race category has a higher representation in both income categories ('>50K' and '<=50K').
#
# -> This indicates that the majority of the dataset consists of individuals of White race, and their income distribution spans      both income levels.
#
# **Black:
#
# -> The 'Black' race category has a higher count in the '<=50K' income category.
#
# -> This suggests that individuals of Black race are more likely to have lower incomes.
#
# **Asian-Pac-Islander:
#
# -> The 'Asian-Pac-Islander' race category has a mix of individuals in both income categories, but with a slightly higher count    in the '>50K' income category.
#
# -> This indicates that individuals of Asian-Pac-Islander race are more likely to have higher incomes compared to the '<=50K'      income category.
#
# **Amer-Indian-Eskimo and Other:
#
# -> 'Amer-Indian-Eskimo' and 'Other' race categories have relatively lower counts compared to 'White', 'Black', and 'Asian-Pac-      Islander'.
#
# -> Both categories show a higher count in the '<=50K' income category, indicating lower incomes on average.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='gender', hue='income', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('gender Level')
plt.ylabel('Count')
plt.title('Gender Level vs. Income',fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Male:
#
# -> The 'Male' gender category has a higher representation in both income categories ('>50K' and '<=50K').
#
# -> This indicates that the dataset has more males, and their income distribution spans both income levels.
#
# **Female:
#
# -> The 'Female' gender category has a higher count in the '<=50K' income category.
#
# -> This suggests that females are more likely to have lower incomes compared to males.

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='workclass', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Workclass')
plt.ylabel('Age')
plt.title('Age vs. Workclass vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Private Workclass:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Self-employed Workclass:
#
# -> The distributions for both income levels appear to have a similar shape, with income '>50K' having a slightly wider            distribution.
#
# -> The median age for both income levels is quite close.
#
# **Other Workclass:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.
#
# **Government Workclass:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='education', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Education')
plt.ylabel('Age')
plt.title('Age vs. Education vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Some College Education:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Bachelors Education:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **HS Grad Education:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Masters Education:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='marital-status', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Marital-status')
plt.ylabel('Age')
plt.title('Age vs. Mariatl-status vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Married-civ-spouse:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Never-married:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.
#
# **Divorced:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Separated:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='occupation', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Occupation')
plt.ylabel('Age')
plt.title('Age vs. Occupation vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Prof-specialty:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Craft-repair:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Exec-managerial:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Adm-clerical:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='relationship', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Relationship')
plt.ylabel('Age')
plt.title('Age vs. Relationship vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Husband:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# ->The median age for income '>50K' is higher than for income '<=50K'.
#
# **Not-in-family:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.
#
# **Own-child:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Unmarried:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='race', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Race')
plt.ylabel('Age')
plt.title('Age vs. Race vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **White:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Black:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.
#
# **Asian-Pac-Islander:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Amer-Indian-Eskimo:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='gender', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age vs. Gender vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **Male:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Female:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='native-country', y='age', hue='income', data=df, split=True, inner='quartile', palette='muted')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Native-country')
plt.ylabel('Age')
plt.title('Age vs. Native-country vs. Income')
plt.legend(title='Income', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
#
# **United-States:
#
# -> The distribution of age for income '>50K' seems to have a wider range compared to the distribution for income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Mexico:
#
# -> The distribution of age for income '>50K' is more spread out compared to income '<=50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.
#
# **Philippines:
#
# -> The distribution of age for income '>50K' is more concentrated around the median compared to income '<=50K'.
#
# -> The median age for income '>50K' is higher than for income '<=50K'.
#
# **Germany:
#
# -> Both income levels have similar age distributions, with a slightly wider distribution for income '>50K'.
#
# -> The median age for income '>50K' is slightly higher than for income '<=50K'.

# %% [markdown]
# # Correlation of different parameters

# %%
df.income = df.income.replace('<=50K',0)
df.income = df.income.replace('>50K',1)
num_columns = df.select_dtypes(include=['number'])

df.income
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 48842, dtype: int64

# %%
plt.figure(figsize = (12,10))
plt.title("Correlation ", fontweight = 'bold')
sns.heatmap(num_columns.corr(), annot = True)
plt.xticks( rotation = 90)
plt.yticks( rotation = 90)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Observation
#
# **Age and Income:
#
# -> There is a moderate positive correlation between age and income. This suggests that older individuals tend to have higher      incomes.
#
# -> Educational-Num and Income: There is a moderate positive correlation between educational-num and income. This indicates that   individuals with higher levels of education tend to have higher incomes.
#
# **Capital-Gain and Income:
#
# -> There is a positive correlation between capital-gain and income. This implies that individuals with higher capital gains        tend to have higher incomes.
#
# **Capital-Loss and Income:
#
# -> There is a negative correlation between capital-loss and income. This suggests that individuals with higher capital losses      tend to have lower incomes.
#
# **Hours-per-Week and Income:
#
# -> There is a positive correlation between hours-per-week and income. This indicates that individuals who work longer hours per    week tend to have higher incomes.

# %% [markdown]
# # Factors that are affecting

# %% [markdown]
# **Education:
#
# -> Relation to Income: There is a strong positive correlation between education and income. Higher levels of education            generally result in higher income.
#
# -> Higher education levels lead to access to higher-paying jobs and professions.
#
# **Occupation:
#
# -> Relation to Income: Occupation plays a significant role in determining income. Certain occupations like Exec-managerial and   Prof-specialty tend to have higher incomes compared to others.
#
# -> Certain occupations offer higher salaries due to specialized skills and responsibilities.
#
# **Age:
#
# -> Relation to Income: There is a moderate positive correlation between age and income. Older individuals generally have higher    incomes.
#
# -> Experience and career progression often result in higher incomes.
#
# **Work Hours per Week:
#
# -> Relation to Income: There is a positive correlation between hours worked per week and income. Individuals who work more        hours tend to have higher incomes.
#
# -> More hours worked can lead to higher earnings through overtime and bonuses.
#
# **Capital Gain and Capital Loss:
#
# -> Relation to Income: Both capital gain and capital loss can affect income, although the correlations are not as strong.
#
# -> Reflects investment decisions and financial management.
#
# **Marital Status:
#
# -> Relation to Income: Married individuals, especially those in a "Married-civ-spouse" status, tend to have higher incomes on average.
#
# -> Shared financial responsibilities and stability in relationships.
#
# **Race and Gender:
#
# -> Relation to Income: There are disparities in income based on race and gender. For example, White individuals and males tend to have higher average incomes.
#
# -> Systemic inequalities and biases in the job market.
